# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # 1. Regression with PyTorch

# %%
from bike_regression import NNBikeRegression

# create an object from the data source
nn_bike_regression = NNBikeRegression(
    'data/capital-bike-share-2010-2023-grouped.csv',
    ['temp', 'hour', 'month'],
    ['total_trips'],
)

# %%
# split the data into train and test
nn_bike_regression.split()

# %%
print("X", nn_bike_regression.X.shape)
display(nn_bike_regression.X.head())
print("y", nn_bike_regression.y.shape)
display(nn_bike_regression.y.head())
# Out:
# X (55080, 3)
#    temp  hour  month
# 0  11.9     0      9
# 1  12.0     1      9
# 2  13.4     2      9
# 3  14.8     3      9
# 4  15.8     4      9
# y (55080, 1)
#    total_trips
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0

# %%
# train the model
nn_bike_regression.train(500)
# Out:
# Epoch: 01/500 Loss: 71785.5078125000
# Epoch: 02/500 Loss: 71785.5078125000
# Epoch: 03/500 Loss: 71785.5078125000
# Epoch: 04/500 Loss: 71785.5078125000
# Epoch: 05/500 Loss: 71785.5078125000
# Epoch: 06/500 Loss: 71785.5078125000
# Epoch: 07/500 Loss: 71785.5078125000
# Epoch: 08/500 Loss: 71785.5078125000
# Epoch: 09/500 Loss: 71785.5078125000
# Epoch: 10/500 Loss: 71785.5078125000
# Epoch: 11/500 Loss: 71785.5078125000
# Epoch: 12/500 Loss: 71785.5078125000
# Epoch: 13/500 Loss: 71785.5078125000
# Epoch: 14/500 Loss: 71785.5078125000
# Epoch: 15/500 Loss: 71785.5078125000
# Epoch: 16/500 Loss: 71785.5078125000
# Epoch: 17/500 Loss: 71785.5078125000
# Epoch: 18/500 Loss: 71785.5078125000
# Epoch: 19/500 Loss: 71785.5078125000
# Epoch: 20/500 Loss: 71785.5078125000
# Epoch: 21/500 Loss: 71785.5078125000
# Epoch: 22/500 Loss: 71785.5078125000
# Epoch: 23/500 Loss: 71785.5078125000
# Epoch: 24/500 Loss: 71785.5078125000
# Epoch: 25/500 Loss: 71785.5078125000
# ...

# %%
nn_bike_regression.evaluate()
# Out:
# Loss: 71161.6484375000

# %%
nn_bike_regression.plot()
